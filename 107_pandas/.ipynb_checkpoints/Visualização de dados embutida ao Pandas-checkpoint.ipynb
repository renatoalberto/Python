# %% [markdown]
# ## Curso - Python para Data Science e Machine Learning - COMPLETO

# %% [markdown]
# #### Professor: Jose Portilla,
# aula: 56

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt

# %%
# Aplicar um estilo aos gráficos
# plt.style.use('fivethirtyeight')
plt.style.use('fast')

# %%
df1 = pd.read_csv('df1', index_col=0)
display(df1.shape)
df1.head()
# Out:
# (1000, 4)
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3 = pd.read_csv('df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ### hist() - histograma

# %%
df1['A'].plot.hist(bins=50)

# %%
# plot sendo omitido
df1['A'].hist(bins=50)

# %%
df2.plot.area(alpha=0.4)

# %%
# stacked - para visualizar numa mesma coluna
df2.plot.bar(stacked=True)

# %%
df1.plot.line(y='B', figsize=(12,5), lw=1)

# %%
# Gráfico de dispersão A em relação ao B
# Onde o parâmetro C fará a distinção por cores
# cmap para paleta de cores
df1.plot.scatter(x='A', y='B', c='C', cmap='inferno')

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['A', 'B'])
df.head()
# Out:
#           A         B
# 0  0.830655  0.684902
# 1  0.184935  0.648913
# 2  0.869906  0.351388
# 3  0.543920  0.055629
# 4  0.720445  0.160055

# %%
# Gráfico hexagonal
# gridsize para tamanho dos hexagonos
df.plot.hexbin(x='A', y='B', gridsize=20, cmap='Oranges')

# %%
df2.plot.kde()
